# %% [markdown]
# # 문제 설명
# - 백준 1158번 실버4
# - 큐 / 구현 문제
# - 시간 제한: 2초, 메모리 제한: 256MB
#
# ![image.png](attachment:image.png)
#
# ## 포인트
# - 유명한 요세푸스 문제
# - 처음엔 i 변수로 계속 사람을 따라 갈랬는데
#   - 그렇게 짜면 좀 구현이 어려워지긴함
#   - 그래서 걍 어차피 K-1번만 pop해주고 pop해준 값을 또 뒤에 push해주면
#   - i값으로 컨트롤 안해도댐

# %%
from collections import deque

def solution(N, K):
    dq = deque([i for i in range(1, N+1)])
    result = []
    
    while dq:
        for _ in range(K-1):
            dq.append(dq.popleft())
        result.append(dq.popleft())
    
    print('<', end='')
    print(', '.join(map(str, result)), end='')
    print('>')

N, K = map(int, input().split())
solution(N, K)
